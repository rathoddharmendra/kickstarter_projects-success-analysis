# %% [markdown]
# <a href="https://colab.research.google.com/github/rathoddharmendra/kickstarter-platform-analysis/blob/main/kickstarter_platform_analysis_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Finding median for the funding-per-project metric

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go

# %%
# from google.colab import auth

# # Authenticate your Google account
# auth.authenticate_user()

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

creds = service_account.Credentials.from_service_account_file("/content/storiesmitdee.json")
client = bigquery.Client(credentials=creds, project='data-analytics-ns-470609')

# %% [markdown]
# ## Working on various KPIs

# %%
query = """
SELECT
  -- APPROX_QUANTILES(funding_per_project, 100)[OFFSET(50)] AS median_funding_per_project
  *
FROM `data-analytics-ns-470609.kickstarter_project_analysis.ks-projects-clean`
"""

df = client.query(query).to_dataframe()
df.head()
# Out:
#                 ID                                               name  \
# 0        657667332     help me get a 3d printer please!!! (Suspended)
# 1       1783647458  Online 3D Printing Marketplace + Local printin...
# 2        474745489                                      Image to Life
# 3       1853034878  Modular 3D Printing Kit, a DYI RepRap Anyone C...
# 4       1015381354     Krimson Titan Customs: Project Onyx (Canceled)
# ...            ...                                                ...
# 375087  1929840910                              Double Fine Adventure
# 375088  1755266685                    The Veronica Mars Movie Project
# 375089   557230947  Bring Reading Rainbow Back for Every Child, Ev...
# 375090  1386523707                      Fidget Cube: A Vinyl Desk Toy
# 375091  1955357092                                  Exploding Kittens
#
#               category main_category currency    deadline       goal  \
# 0          3D Printing    Technology      USD  2015-03-29     3500.0
# 1          3D Printing    Technology      EUR  2014-11-03   100000.0
# 2          3D Printing    Technology      USD  2017-07-17   100000.0
# 3          3D Printing    Technology      USD  2015-09-16     5000.0
# 4          3D Printing    Technology      USD  2015-09-05     1200.0
# ...                ...           ...      ...         ...        ...
# 375087     Video Games         Games      USD  2012-03-14   400000.0
# 375088  Narrative Film  Film & Video      USD  2013-04-13  2000000.0
# 375089             Web    Technology      USD  2014-07-02  1000000.0
# 375090  Product Design        Design      USD  2016-10-20    15000.0
# 375091  Tabletop Games         Games      USD  2015-02-20    10000.0
#
#                         launched     pledged       state  backers country  \
# 0      2015-02-27 06:27:40+00:00        0.00   suspended        0      US
# 1      2014-10-04 08:04:23+00:00        0.00      failed        0      NL
# 2      2017-06-17 00:44:29+00:00        0.00      failed        0      US
# 3      2015-08-17 21:49:29+00:00        0.00    canceled        0      US
# 4      2015-08-06 17:32:15+00:00        0.00    canceled        0      US
# ...                          ...         ...         ...      ...     ...
# 375087 2012-02-09 02:52:52+00:00  3336371.92  successful    87142      US
# 375088 2013-03-13 15:42:22+00:00  5702153.38  successful    91585      US
# 375089 2014-05-28 15:05:45+00:00  5408916.95  successful   105857      US
# 375090 2016-08-30 22:02:09+00:00  6465690.30  successful   154926      US
# 375091 2015-01-20 19:00:19+00:00  8782571.99  successful   219382      US
#
#         status
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 375087       1
# 375088       1
# 375089       1
# 375090       1
# 375091       1
#
# [375092 rows x 13 columns]

# %%
df['pledged'].median()
# Out:
# 620.0

# %% [markdown]
# *median per project* - goal: 5500 vs pledged: 620

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375092 entries, 0 to 375091
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             375092 non-null  Int64
#  1   name           375088 non-null  object
#  2   category       375092 non-null  object
#  3   main_category  375092 non-null  object
#  4   currency       375092 non-null  object
#  5   deadline       375092 non-null  dbdate
#  6   goal           375092 non-null  float64
#  7   launched       375092 non-null  datetime64[us, UTC]
#  8   pledged        375092 non-null  float64
#  9   state          375092 non-null  object
#  10  backers        375092 non-null  Int64
#  11  country        375092 non-null  object
#  12  status         375092 non-null  Int64
# dtypes: Int64(3), datetime64[us, UTC](1), dbdate(1), float64(2), object(6)
# memory usage: 38.3+ MB

# %%
df.describe()
# Out:
#                       ID          goal       pledged     backers    status
# count           375092.0  3.750920e+05  3.750920e+05    375092.0  375092.0
# mean   1074635644.384807  4.950586e+04  9.753464e+03  106.622426  0.364591
# std     619130372.943478  1.189000e+06  9.608663e+04  911.431981  0.481316
# min               5971.0  1.000000e-02  0.000000e+00         0.0       0.0
# 25%          538080126.0  2.000000e+03  3.100000e+01         2.0       0.0
# 50%         1075218664.0  5.500000e+03  6.200000e+02        12.0       0.0
# 75%        1610133769.25  1.650000e+04  4.080000e+03        57.0       1.0
# max         2147476221.0  1.000000e+08  2.033899e+07    219382.0       1.0

# %%
## median per projects - for successful projects
df['pledged'][df['status'] == 1].median()
# Out:
# 5051.0

# %%
# px.bar(df.pledged)

# %%
## /* choosing median over mean as it is less affected by outliers */
# 5. **Top Subcategories by Money Raised**
# Which niches raise the most.

df.groupby('main_category')['pledged'].median().sort_values(ascending=False)
# Out:
# main_category
# Design          1990.0
# Dance           1825.0
# Theater         1500.0
# Comics          1480.0
# Games           1282.5
# Music           1005.0
# Film & Video     736.0
# Art              424.0
# Technology       331.0
# Publishing       290.0
# Food             255.0
# Fashion          240.0
# Photography      235.0
# Crafts            95.0
# Journalism        51.0
# Name: pledged, dtype: float64

# %%
px.bar(df.groupby('main_category')['pledged'].median().sort_values(ascending=False))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e9df2594-f5f4-407a-b85f-ec467f8eff66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9df2594-f5f4-407a-b85f-ec467f8eff66")) {                    Plotly.newPlot(                        "e9df2594-f5f4-407a-b85f-ec467f8eff66",                        [{"alignmentgroup":"True","hovertemplate":"variable=pledged\u003cbr\u003emain_category=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pledged","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"pledged","offsetgroup":"pledged","orientation":"v","showlegend":true,"textposition":"auto","x":["Design","Dance","Theater","Comics","Games","Music","Film & Video","Art","Technology","Publishing","Food","Fashion","Photography","Crafts","Journalism"],"xaxis":"x","y":[1990.0,1825.0,1500.0,1480.0,1282.5,1005.0,736.0,424.0,331.0,290.0,255.0,240.0,235.0,95.0,51.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{" ...

# %%
df.category.value_counts()
# Out:
# category
# Product Design     22312
# Documentary        16138
# Tabletop Games     14180
# Music              13493
# Shorts             12357
#                    ...
# Residencies           69
# Letterpress           49
# Chiptune              35
# Literary Spaces       27
# Taxidermy             13
# Name: count, Length: 159, dtype: int64

# %%
df['deadline'] = pd.to_datetime(df['deadline'], errors='raise')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375092 entries, 0 to 375091
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             375092 non-null  Int64
#  1   name           375088 non-null  object
#  2   category       375092 non-null  object
#  3   main_category  375092 non-null  object
#  4   currency       375092 non-null  object
#  5   deadline       375092 non-null  datetime64[ns]
#  6   goal           375092 non-null  float64
#  7   launched       375092 non-null  datetime64[us, UTC]
#  8   pledged        375092 non-null  float64
#  9   state          375092 non-null  object
#  10  backers        375092 non-null  Int64
#  11  country        375092 non-null  object
#  12  status         375092 non-null  Int64
# dtypes: Int64(3), datetime64[ns](1), datetime64[us, UTC](1), float64(2), object(6)
# memory usage: 38.3+ MB

# %%
# 6. **Average Campaign Duration (days)**

df['campaign_duration'] = (df['deadline'] - df['launched']).dt.days

# %%
df['campaign_duration'].value_counts()
# Out:
# campaign_duration
# 29    167536
# 59     33318
# 44     17643
# 30     13119
# 34     10020
#        ...
# 82        54
# 76        52
# 73        46
# 78        39
# 91        22
# Name: count, Length: 92, dtype: int64

# %%
df.groupby(df['campaign_duration'].value_counts())['status'].sum().sort_values(ascending=True)
# Out:
# count
# 22.0        0
# 39.0        0
# 46.0        0
# 52.0        0
# 54.0        0
#            ..
# 10020.0     0
# 13119.0     0
# 17643.0     0
# 33318.0     0
# 167536.0    0
# Name: status, Length: 88, dtype: Int64

# %%
df.campaign_duration.median()
# Out:
# 29.0

# %%
## avg campaign duration for successful and failed projecsts (from status category)

df.groupby('status')['campaign_duration'].median()
# Out:
# status
# 0    29.0
# 1    29.0
# Name: campaign_duration, dtype: float64

# %%
df.groupby('main_category')['campaign_duration'].median().sort_values(ascending=False)
# Out:
# main_category
# Art             29.0
# Comics          29.0
# Crafts          29.0
# Dance           29.0
# Design          29.0
# Fashion         29.0
# Film & Video    29.0
# Food            29.0
# Games           29.0
# Journalism      29.0
# Music           29.0
# Photography     29.0
# Publishing      29.0
# Technology      29.0
# Theater         29.0
# Name: campaign_duration, dtype: float64

# %%
# 7. **Average Backers per Project**

df['backers'].mean()
# Out:
# np.float64(106.62242596482996)

# %%
df.groupby('main_category')['backers'].median().sort_values(ascending=False)
# Out:
# main_category
# Comics          40.0
# Design          29.0
# Games           29.0
# Dance           27.0
# Theater         24.0
# Music           18.0
# Film & Video    12.0
# Art             10.0
# Publishing       7.0
# Technology       7.0
# Food             6.0
# Photography      6.0
# Fashion          5.0
# Crafts           3.0
# Journalism       2.0
# Name: backers, dtype: Float64

# %%
# 8. **Geographical Distribution**

df.groupby('country')['status'].sum().sort_values(ascending=False)
# Out:
# country
# US      111039
# GB       12346
# CA        4266
# AU        2080
# DE        1012
# FR         960
# NL         652
# ES         544
# SE         529
# IT         515
# MX         503
# NZ         459
# DK         376
# HK         251
# IE         218
# SG         206
# CH         201
# NO         170
# BE         164
# AT         122
# N,0"       106
# LU          20
# JP          16
# Name: status, dtype: Int64

# %%
px.bar(df.groupby('country')['status'].sum().sort_values(ascending=False))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="61a6292c-ac55-4d2e-89b1-3055089dfc30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61a6292c-ac55-4d2e-89b1-3055089dfc30")) {                    Plotly.newPlot(                        "61a6292c-ac55-4d2e-89b1-3055089dfc30",                        [{"alignmentgroup":"True","hovertemplate":"variable=status\u003cbr\u003ecountry=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"status","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"status","offsetgroup":"status","orientation":"v","showlegend":true,"textposition":"auto","x":["US","GB","CA","AU","DE","FR","NL","ES","SE","IT","MX","NZ","DK","HK","IE","SG","CH","NO","BE","AT","N,0\"","LU","JP"],"xaxis":"x","y":[111039,12346,4266,2080,1012,960,652,544,529,515,503,459,376,251,218,206,201,170,164,122,106,20,16],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2 ...

# %%
# vs the no of pitches from countries
df.groupby('country')['status'].count().sort_values(ascending=False)
# Out:
# country
# US      292621
# GB       33672
# CA       14756
# AU        7839
# DE        4171
# FR        2939
# IT        2878
# NL        2868
# ES        2276
# SE        1757
# MX        1752
# NZ        1447
# DK        1113
# IE         811
# CH         760
# NO         708
# HK         618
# BE         617
# AT         597
# SG         555
# N,0"       235
# LU          62
# JP          40
# Name: status, dtype: Int64

# %%
px.bar(df.groupby('country')['status'].count().sort_values(ascending=False))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bce9c7fd-e4cf-4d8d-be62-5dc300e97880" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bce9c7fd-e4cf-4d8d-be62-5dc300e97880")) {                    Plotly.newPlot(                        "bce9c7fd-e4cf-4d8d-be62-5dc300e97880",                        [{"alignmentgroup":"True","hovertemplate":"variable=status\u003cbr\u003ecountry=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"status","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"status","offsetgroup":"status","orientation":"v","showlegend":true,"textposition":"auto","x":["US","GB","CA","AU","DE","FR","IT","NL","ES","SE","MX","NZ","DK","IE","CH","NO","HK","BE","AT","SG","N,0\"","LU","JP"],"xaxis":"x","y":[292621,33672,14756,7839,4171,2939,2878,2868,2276,1757,1752,1447,1113,811,760,708,618,617,597,555,235,62,40],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"c ...
